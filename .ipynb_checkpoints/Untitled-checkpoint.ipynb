# %%
# 라이브러리 임포트
import requests
import pandas as pd
import time
from io import StringIO
from bs4 import BeautifulSoup
from langchain_text_splitters import RecursiveCharacterTextSplitter
import yfinance as yf
import plotly.graph_objects as go

# %%
#종목 검색 함수
def is_korean(text):
    return any("\uAC00" <= c <= "\uD7A3" for c in text)

def get_stock_code(stock_name):
    url = "https://kind.krx.co.kr/corpgeneral/corpList.do?method=download"
    response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
    response.encoding = "euc-kr"
    df = pd.read_html(StringIO(response.text))[0]
    df["종목코드"] = df["종목코드"].astype(str).str.strip()
    result = df[df["회사명"] == stock_name]["종목코드"]
    return result.values[0] if not result.empty else None

def translate_to_english(korean_name):
    url = "https://translate.googleapis.com/translate_a/single"
    params = {"client": "gtx", "sl": "ko", "tl": "en", "dt": "t", "q": korean_name}
    try:
        response = requests.get(url, params=params)
        return response.json()[0][0][0]
    except:
        return None

def get_yahoo_ticker(query):
    url = "https://query2.finance.yahoo.com/v1/finance/search"
    params = {"q": query, "lang": "en-US", "region": "US"}
    headers = {"User-Agent": "Mozilla/5.0"}
    try:
        response = requests.get(url, params=params, headers=headers)
        quotes = response.json().get("quotes", [])
        return quotes[0]["symbol"] if quotes else None
    except:
        return None

def search_stock(stock_name):
    if stock_name.isdigit() and len(stock_name) == 6:
        print(f"✅ [국내] 종목코드 직접 입력 → {stock_name}")
        return {"type": "KR", "code": stock_name, "name": stock_name}
    
    if is_korean(stock_name):
        code = get_stock_code(stock_name)
        if code:
            print(f"✅ [국내] {stock_name} → {code}")
            return {"type": "KR", "code": code, "name": stock_name}
        
        print(f"🔄 '{stock_name}' 번역 중...")
        english_name = translate_to_english(stock_name)
        print(f"🔄 번역 결과: {english_name}")
        
        if english_name:
            ticker = get_yahoo_ticker(english_name)
            if ticker:
                print(f"✅ [해외] {stock_name} → 티커: {ticker}")
                return {"type": "US", "code": ticker, "name": stock_name}
        
        print(f"❌ '{stock_name}'을 찾을 수 없어요.")
        print(f"💡 힌트: 영문명이나 티커로 직접 입력해보세요!")
        return None
    
    else:
        ticker = get_yahoo_ticker(stock_name)
        if ticker:
            print(f"✅ [해외] {stock_name} → 티커: {ticker}")
            return {"type": "US", "code": ticker, "name": stock_name}
        print(f"❌ '{stock_name}'을 찾을 수 없어요.")
        return None

# %%
# 뉴스 크롤링 함수
def get_article_body(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36",
        "Referer": "https://finance.naver.com"
    }
    try:
        # 1단계: 원래 URL 요청
        response = requests.get(url, headers=headers)
        response.encoding = "euc-kr"
        
        # 2단계: JS 리다이렉트 URL 추출
        if "top.location.href=" in response.text:
            import re
            match = re.search(r"top\.location\.href='(.+?)'", response.text)
            if match:
                real_url = match.group(1)
                response = requests.get(real_url, headers=headers)
                response.encoding = "utf-8"
        
        soup = BeautifulSoup(response.text, "html.parser")
        
        # n.news.naver.com 셀렉터
        selectors = [
            "div#dic_area",        # 네이버 뉴스 본문
            "div.newsct_article",  # 네이버 뉴스 본문 (구버전)
            "div#news_read",
            "div#contents",
        ]
        for selector in selectors:
            body = soup.select_one(selector)
            if body and body.text.strip():
                return body.text.strip()
        return ""
    except:
        return ""

def get_naver_finance_news(stock_info, num_articles=20):
    code = stock_info["code"]
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36",
        "Referer": "https://finance.naver.com"
    }
    results = []
    existing_links = set()  
    page = 1
    
    while len(results) < num_articles:
        url = f"https://finance.naver.com/item/news_news.naver?code={code}&page={page}"
        response = requests.get(url, headers=headers)
        response.encoding = "euc-kr"
        soup = BeautifulSoup(response.text, "html.parser")
        articles = soup.select("td.title a")
        
        if not articles:
            break
        
        for article in articles:
            if len(results) >= num_articles:
                break
            title = article.text.strip()
            link = "https://finance.naver.com" + article["href"]
            
            if link in existing_links:  
                continue
            
            body = get_article_body(link)
            results.append({"title": title, "link": link, "body": body})
            existing_links.add(link)
            time.sleep(0.3)
            print(f"✅ 수집완료 ({len(results)}/{num_articles}): {title[:30]}...")
        
        page += 1
        time.sleep(1)
    
    return results

def get_yahoo_news(ticker, num_articles=20):
    """yfinance로 해외 종목 뉴스 수집"""
    try:
        stock = yf.Ticker(ticker)
        news_data = stock.news
        
        if not news_data:
            print(f"❌ {ticker} 뉴스를 찾을 수 없어요!")
            return []
        
        results = []
        for item in news_data[:num_articles]:
            title = item.get("content", {}).get("title", "")
            link = item.get("content", {}).get("canonicalUrl", {}).get("url", "")
            summary = item.get("content", {}).get("summary", "")
            
            if title:
                results.append({
                    "title": title,
                    "link": link,
                    "body": summary
                })
                print(f"✅ 수집완료: {title[:30]}...")
        
        return results
    except Exception as e:
        print(f"❌ 오류 발생: {e}")
        return []


def get_news(stock_info, num_articles=20):
    if stock_info["type"] == "KR":
        print(f"📰 네이버 금융에서 수집 중...")
        return get_naver_finance_news(stock_info, num_articles)
    else:
        print(f"📰 야후 파이낸스에서 수집 중...")
        return get_yahoo_news(stock_info["code"], num_articles)

def get_stock_chart(stock_info, period="3mo"):
    try:
        if stock_info["type"] == "KR":
            ticker = stock_info["code"] + ".KS"
        else:
            ticker = stock_info["code"]
        
        stock = yf.Ticker(ticker)
        df = stock.history(period=period)
        
        if df.empty:
            return None
        
        fig = go.Figure()
        fig.add_trace(go.Candlestick(
            x=df.index,
            open=df["Open"],
            high=df["High"],
            low=df["Low"],
            close=df["Close"],
            name="주가"
        ))
        
        fig.update_layout(
            title=f"{stock_info['name']} 주가",
            xaxis_rangeslider_visible=False,
            height=400
        )
        
        return fig
    except:
        return None

# %%
# ChromaDB 벡터 저장
import re
import warnings
warnings.filterwarnings("ignore")

from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_core.documents import Document

def store_to_chromadb(news_list, stock_name, stock_code):
    
    splitter = RecursiveCharacterTextSplitter(
        chunk_size=300,
        chunk_overlap=50
    )
    
    docs = []
    for news in news_list:
        if news["body"]:
            chunks = splitter.split_text(news["body"])
            for chunk in chunks:
                docs.append(Document(
                    page_content=chunk,
                    metadata={"title": news["title"], "link": news["link"]}
                ))
    
    if not docs:
        return None
    
    print(f"청킹 완료: 뉴스 {len(news_list)}개 → 청크 {len(docs)}개")
    
    embedding_model = HuggingFaceEmbeddings(
        model_name="BAAI/bge-m3",
        model_kwargs={"device": "cpu"},
        encode_kwargs={"normalize_embeddings": True}
    )
    
    vectorstore = Chroma.from_documents(
        documents=docs,
        embedding=embedding_model,
        persist_directory=f"./chroma_db/{stock_code}",
        collection_name=f"news_{stock_code}"
    )
    
    print(f"✅ {len(docs)}개 청크 벡터 저장 완료!")
    return vectorstore

# %%
stock_name = input("🔍 종목명을 입력하세요 (예: 삼성전자 / 엔비디아 / TSLA / 005930): ").strip()
result = search_stock(stock_name)

if result:
    news = get_news(result, num_articles=20)
    print(f"\n총 {len(news)}개 기사 수집 완료!")
    
    for i, n in enumerate(news):
        print(f"\n[{i+1}] {n['title']}")
        print(f"     본문길이: {len(n['body'])}자")
    
    vectorstore = store_to_chromadb(news, result["name"], result["code"])
# Out:
# 🔍 종목명을 입력하세요 (예: 삼성전자 / 엔비디아 / TSLA / 005930):  테슬라
# 🔄 '테슬라' 번역 중...
# 🔄 번역 결과: tesla
# ✅ [해외] 테슬라 → 티커: TSLA
# 📰 야후 파이낸스에서 수집 중...
# ✅ 수집완료: General Motors follows Ford's ...
# ✅ 수집완료: TSLA Stock Sinks As SpaceX IPO...
# ✅ 수집완료: S&P 500, Nasdaq, Dow Futures E...
# ✅ 수집완료: Cathie Wood Asks Elon Musk How...
# ✅ 수집완료: Why SpaceX (SPCX) Could Trade ...
# ✅ 수집완료: S&P 500, Nasdaq, Dow Drop As U...
# ✅ 수집완료: SpaceX: Why This $1.6 Trillion...
# ✅ 수집완료: Here's Why Tesla (TSLA) Fell M...
# ✅ 수집완료: The Model 3 Era at Rivian Begi...
# ✅ 수집완료: TSLA Stock Watches SpaceX IPO ...
#
# 총 10개 기사 수집 완료!
#
# [1] General Motors follows Ford's lead into the battery business
#      본문길이: 289자
#
# [2] TSLA Stock Sinks As SpaceX IPO Nears — Analyst Says Investors Are Selling Tesla To Catch A Day-1 Pop In Next Musk Trade
#      본문길이: 120자
#
# [3] S&P 500, Nasdaq, Dow Futures Extend Slide As US-Iran Hormuz Tensions Flare Again, Inflation Data Stings: ORCL, DJT, SMCI, TSLA In Focus
#      본문길이: 121자
#
# [4] Cathie Wood Asks Elon Musk How Tesla Handles 'Parking And Traffic Violations' After The Robotaxi She Rode Gets $75 Ticket
#      본문길이: 242자
#
# [5] Why SpaceX (SPCX) Could Trade Like Tesla On Steroids
#      본문길이: 208자
#
# [6] S&P 500, Nasdaq, Dow Drop As US-Iran War Jitters, Inflation Risk Spur Tech Selloffs  — SMCI, AMZN, OPEN, SEGG, TSLA In Focus
#      본문길이: 97자
#
# [7] SpaceX: Why This $1.6 Trillion Opportunity Is Critical for the Upcoming IPO
#      본문길이: 61자
#
# [8] Here's Why Tesla (TSLA) Fell More Than Broader Market
#      본문길이: 103자
#
# [9] The Model 3 Era at Rivian Begins. Its Lower-Price EV Is Here.
#      본문길이: 282자
#
# [10] TSLA Stock Watches SpaceX IPO While Cheapest Cybertruck Hits Driveways After Long Wait
#      본문길이: 88자
# 청킹 완료: 뉴스 10개 → 청크 10개
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# ✅ 10개 청크 벡터 저장 완료!

# %%
#RAG 체인 구성
from langchain_ollama import OllamaLLM
from langchain_core.prompts import PromptTemplate
from langchain_classic.chains import RetrievalQA 

def build_rag_chain(vectorstore):
    llm = OllamaLLM(model="llama3.2", temperature=0.1)
    prompt_template = """
당신은 주식 뉴스 분석 전문가입니다.
아래 뉴스 기사들을 바탕으로 질문에 답해주세요.
반드시 한국어로 답변하고, 핵심 이슈를 간결하게 정리해주세요.

[참고 뉴스]
{context}

[질문]
{question}

[분석 결과]
"""
    PROMPT = PromptTemplate(
        template=prompt_template,
        input_variables=["context", "question"]
    )
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=vectorstore.as_retriever(search_kwargs={"k": 5}),
        chain_type_kwargs={"prompt": PROMPT},
        return_source_documents=True  
    )
    return qa_chain

# %%
# RAG 체인 생성
chain = build_rag_chain(vectorstore)

# 질문
query = input("💬 질문을 입력하세요: ").strip()
result = chain.invoke({"query": query})
print("\n📊 분석 결과:")
print(result["result"])
# Out:
# 💬 질문을 입력하세요:  최근 주요 이슈는?
# 📊 분석 결과:
# 최근 주요 이슈는 SpaceX의 성장 기회와 US-Iran 간의 तन정과 미국의 인플레이션 데이터가 주식ตลาด에 미치는 영향을 다루고 있습니다.
#
# SpaceX의 새로운 제품이 출시된 것으로 알려져 있으며, 이로 인해 주식 가격이 급격히 상승할 수 있는 상황이 arise하고 있습니다. 또한, US-Iran 간의 तन정과 미국의 인플레이션 데이터가 주식ตลาด에 미치는 영향을 다루고 있습니다.
#
# SpaceX의 성장 기회는 scarcity, cult following 및 새로운 제품의 story가 주로 인해 발생하는 것으로 알려져 있으며, 이러한 요인들이 주식 가격에 미치는 영향을 분석해야 합니다.

# %%
import yfinance as yf

stock = yf.Ticker("TSLA")
df = stock.history(period="3mo")
print(df.head())
print(len(df))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-03-11 00:00:00-04:00  402.279999  416.380005  402.149994  407.820007
# 2026-03-12 00:00:00-04:00  405.179993  406.500000  394.649994  395.010010
# 2026-03-13 00:00:00-04:00  399.170013  400.200012  389.950012  391.200012
# 2026-03-16 00:00:00-04:00  396.220001  403.730011  394.420013  395.559998
# 2026-03-17 00:00:00-04:00  395.690002  400.119995  393.000000  399.269989
#
#                              Volume  Dividends  Stock Splits
# Date
# 2026-03-11 00:00:00-04:00  62559900        0.0           0.0
# 2026-03-12 00:00:00-04:00  60973800        0.0           0.0
# 2026-03-13 00:00:00-04:00  58504100        0.0           0.0
# 2026-03-16 00:00:00-04:00  58068300        0.0           0.0
# 2026-03-17 00:00:00-04:00  46890500        0.0           0.0
# 64

# %%
import plotly.graph_objects as go
import yfinance as yf

result = {"type": "US", "code": "TSLA", "name": "테슬라"}

ticker = result["code"]
stock = yf.Ticker(ticker)
df = stock.history(period="3mo")

fig = go.Figure()
fig.add_trace(go.Candlestick(
    x=df.index,
    open=df["Open"],
    high=df["High"],
    low=df["Low"],
    close=df["Close"],
    name="주가"
))
fig.update_layout(
    title=f"{result['name']} 3개월 주가",
    xaxis_rangeslider_visible=False,
    height=400
)

fig.show()
