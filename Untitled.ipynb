# %%
# 라이브러리 임포트
import requests
import pandas as pd
import time
from io import StringIO
from bs4 import BeautifulSoup

# %%
#종목 검색 함수
def is_korean(text):
    return any("\uAC00" <= c <= "\uD7A3" for c in text)

def get_stock_code(stock_name):
    url = "https://kind.krx.co.kr/corpgeneral/corpList.do?method=download"
    response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
    response.encoding = "euc-kr"
    df = pd.read_html(StringIO(response.text))[0]
    df["종목코드"] = df["종목코드"].astype(str).str.strip()
    result = df[df["회사명"] == stock_name]["종목코드"]
    return result.values[0] if not result.empty else None

def translate_to_english(korean_name):
    url = "https://translate.googleapis.com/translate_a/single"
    params = {"client": "gtx", "sl": "ko", "tl": "en", "dt": "t", "q": korean_name}
    try:
        response = requests.get(url, params=params)
        return response.json()[0][0][0]
    except:
        return None

def get_yahoo_ticker(query):
    url = "https://query2.finance.yahoo.com/v1/finance/search"
    params = {"q": query, "lang": "en-US", "region": "US"}
    headers = {"User-Agent": "Mozilla/5.0"}
    try:
        response = requests.get(url, params=params, headers=headers)
        quotes = response.json().get("quotes", [])
        return quotes[0]["symbol"] if quotes else None
    except:
        return None

def search_stock(stock_name):
    if stock_name.isdigit() and len(stock_name) == 6:
        print(f"✅ [국내] 종목코드 직접 입력 → {stock_name}")
        return {"type": "KR", "code": stock_name, "name": stock_name}
    
    if is_korean(stock_name):
        code = get_stock_code(stock_name)
        if code:
            print(f"✅ [국내] {stock_name} → {code}")
            return {"type": "KR", "code": code, "name": stock_name}
        
        print(f"🔄 '{stock_name}' 번역 중...")
        english_name = translate_to_english(stock_name)
        print(f"🔄 번역 결과: {english_name}")
        
        if english_name:
            ticker = get_yahoo_ticker(english_name)
            if ticker:
                print(f"✅ [해외] {stock_name} → 티커: {ticker}")
                return {"type": "US", "code": ticker, "name": stock_name}
        
        print(f"❌ '{stock_name}'을 찾을 수 없어요.")
        print(f"💡 힌트: 영문명이나 티커로 직접 입력해보세요!")
        return None
    
    else:
        ticker = get_yahoo_ticker(stock_name)
        if ticker:
            print(f"✅ [해외] {stock_name} → 티커: {ticker}")
            return {"type": "US", "code": ticker, "name": stock_name}
        print(f"❌ '{stock_name}'을 찾을 수 없어요.")
        return None

# %%
# 뉴스 크롤링 함수
def get_article_body(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36",
        "Referer": "https://finance.naver.com"
    }
    try:
        # 1단계: 원래 URL 요청
        response = requests.get(url, headers=headers)
        response.encoding = "euc-kr"
        
        # 2단계: JS 리다이렉트 URL 추출
        if "top.location.href=" in response.text:
            import re
            match = re.search(r"top\.location\.href='(.+?)'", response.text)
            if match:
                real_url = match.group(1)
                response = requests.get(real_url, headers=headers)
                response.encoding = "utf-8"
        
        soup = BeautifulSoup(response.text, "html.parser")
        
        # n.news.naver.com 셀렉터
        selectors = [
            "div#dic_area",        # 네이버 뉴스 본문
            "div.newsct_article",  # 네이버 뉴스 본문 (구버전)
            "div#news_read",
            "div#contents",
        ]
        for selector in selectors:
            body = soup.select_one(selector)
            if body and body.text.strip():
                return body.text.strip()[:500]
        return ""
    except:
        return ""

def get_naver_finance_news(stock_info, num_articles=20):
    code = stock_info["code"]
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36",
        "Referer": "https://finance.naver.com"
    }
    results = []
    existing_links = set()  
    page = 1
    
    while len(results) < num_articles:
        url = f"https://finance.naver.com/item/news_news.naver?code={code}&page={page}"
        response = requests.get(url, headers=headers)
        response.encoding = "euc-kr"
        soup = BeautifulSoup(response.text, "html.parser")
        articles = soup.select("td.title a")
        
        if not articles:
            break
        
        for article in articles:
            if len(results) >= num_articles:
                break
            title = article.text.strip()
            link = "https://finance.naver.com" + article["href"]
            
            if link in existing_links:  
                continue
            
            body = get_article_body(link)
            results.append({"title": title, "link": link, "body": body})
            existing_links.add(link)
            time.sleep(0.3)
            print(f"✅ 수집완료 ({len(results)}/{num_articles}): {title[:30]}...")
        
        page += 1
        time.sleep(1)
    
    return results

def get_yahoo_news(ticker, num_articles=20):
    url = f"https://finance.yahoo.com/quote/{ticker}/news"
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"}
    try:
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, "html.parser")
        articles = soup.select("h3.Mb\\(5px\\) a")[:num_articles]
        results = []
        existing_links = set() 
        for article in articles:
            if len(results) >= num_articles:
                break
            title = article.text.strip()
            link = "https://finance.yahoo.com" + article["href"]  
            
            if link in existing_links:
                continue
            
            results.append({"title": title, "link": link, "body": ""})
            existing_links.add(link)
            print(f"✅ 수집완료: {title[:30]}...")
        return results
    except:
        return []

def get_news(stock_info, num_articles=20):
    if stock_info["type"] == "KR":
        print(f"📰 네이버 금융에서 수집 중...")
        return get_naver_finance_news(stock_info, num_articles)
    else:
        print(f"📰 야후 파이낸스에서 수집 중...")
        return get_yahoo_news(stock_info["code"], num_articles)

# %%
# ChromaDB 벡터 저장
import re
import warnings
warnings.filterwarnings("ignore")

from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_core.documents import Document

def store_to_chromadb(news_list, stock_name, stock_code):  
    docs = [
        Document(
            page_content=f"{news['title']}\n{news['body']}",
            metadata={"title": news["title"], "link": news["link"]}
        )
        for news in news_list if news["body"]
    ]
    
    print(f"📄 총 {len(docs)}개 문서 임베딩 시작...")
    
    if len(docs) == 0:
        print("❌ 저장할 문서가 없어요!")
        return None
    
    embedding_model = HuggingFaceEmbeddings(
        model_name="BAAI/bge-m3",
        model_kwargs={"device": "cpu"},
        encode_kwargs={"normalize_embeddings": True}
    )
    
    collection_name = f"news_{stock_code}"
    
    vectorstore = Chroma.from_documents(
        documents=docs,
        embedding=embedding_model,
        persist_directory=f"./chroma_db/{stock_code}",
        collection_name=collection_name
    )
    
    print(f"✅ {len(docs)}개 문서 벡터 저장 완료!")
    return vectorstore

# %%
stock_name = input("🔍 종목명을 입력하세요 (예: 삼성전자 / 엔비디아 / TSLA / 005930): ").strip()
result = search_stock(stock_name)

if result:
    news = get_news(result, num_articles=20)
    print(f"\n총 {len(news)}개 기사 수집 완료!")
    
    for i, n in enumerate(news):
        print(f"\n[{i+1}] {n['title']}")
        print(f"     본문길이: {len(n['body'])}자")
    
    vectorstore = store_to_chromadb(news, result["name"], result["code"])
# Out:
# 🔍 종목명을 입력하세요 (예: 삼성전자 / 엔비디아 / TSLA / 005930):  삼성전자
# ✅ [국내] 삼성전자 → 005930
# 📰 네이버 금융에서 수집 중...
# ✅ 수집완료 (1/20): 젠슨 황, 첫 韓 예능 출연…“삼성·SK·현대차·네이버...
# ✅ 수집완료 (2/20): 젠슨 황 "이재용·정의선·최태원 훌륭한 리더…매우 행운...
# ✅ 수집완료 (3/20): 반도체 생산직 인기에…'블루칼라'에 눈돌리는 MZ...
# ✅ 수집완료 (4/20): '시총 1위' 엔비디아 젠슨 황, "파산 D-30 딛고...
# ✅ 수집완료 (5/20): 노동장관 "AI 성과 독점 안 돼… 공정한 분배·안전망...
# ✅ 수집완료 (6/20): 삼성전자 성과급에 뿔난 소액주주, 주주명부 열람 소송 ...
# ✅ 수집완료 (7/20): "삼전닉스 직원 성과급은 무효"…분노한 개미들 '집단행...
# ✅ 수집완료 (8/20): 포스코, 반도체·배터리 ‘산업동맥’ 된다…고순도희귀가스...
# ✅ 수집완료 (9/20): "러 특허청, 삼성 'IPS' 상표 등록 퇴짜…LG 상...
# ✅ 수집완료 (10/20): “계약금 2배 돌려줘도 이득” 동탄, 집값 급등에 계약...
# ✅ 수집완료 (11/20): "투자사가 고객"...에임인텔리전스, LG전자·네이버 ...
# ✅ 수집완료 (12/20): "이재용·정의선·최태원 중 '원픽'은"...젠슨 황, ...
# ✅ 수집완료 (13/20): 카카오 첫 파업...'N% 성과급' 확산에 산업계 초긴...
# ✅ 수집완료 (14/20): 카카오 첫 파업...'N% 성과급' 확산에 산업계 초긴...
# ✅ 수집완료 (15/20): 최태원 "반도체 공장, 무조건 한국 아니다"…"전력·땅...
# ✅ 수집완료 (16/20): 코스피 다시 '8천피' 아래로...4.5% 급락 7,7...
# ✅ 수집완료 (17/20): 코스피 다시 '8천피' 아래로...4.5% 급락 7,7...
# ✅ 수집완료 (18/20): 폭락 → 폭등 → 폭락...날마다 급변하는 '롤러코스피...
# ✅ 수집완료 (19/20): [자막뉴스] 시도 때도 없이 울리는 '사이드카'...난...
# ✅ 수집완료 (20/20): 폭락 → 폭등 → 폭락...날마다 급변하는 '롤러코스피...
#
# 총 20개 기사 수집 완료!
#
# [1] 젠슨 황, 첫 韓 예능 출연…“삼성·SK·현대차·네이버, 파트너들 성....
#      본문길이: 500자
#
# [2] 젠슨 황 "이재용·정의선·최태원 훌륭한 리더…매우 행운"
#      본문길이: 500자
#
# [3] 반도체 생산직 인기에…'블루칼라'에 눈돌리는 MZ
#      본문길이: 500자
#
# [4] '시총 1위' 엔비디아 젠슨 황, "파산 D-30 딛고 25년 버텨"
#      본문길이: 500자
#
# [5] 노동장관 "AI 성과 독점 안 돼… 공정한 분배·안전망이 새 사회계약"
#      본문길이: 500자
#
# [6] 삼성전자 성과급에 뿔난 소액주주, 주주명부 열람 소송 나서
#      본문길이: 500자
#
# [7] "삼전닉스 직원 성과급은 무효"…분노한 개미들 '집단행동'
#      본문길이: 500자
#
# [8] 포스코, 반도체·배터리 ‘산업동맥’ 된다…고순도희귀가스 생산 채...
#      본문길이: 500자
#
# [9] "러 특허청, 삼성 'IPS' 상표 등록 퇴짜…LG 상표와 유사"
#      본문길이: 500자
#
# [10] “계약금 2배 돌려줘도 이득” 동탄, 집값 급등에 계약파기 속출
#      본문길이: 500자
#
# [11] "투자사가 고객"...에임인텔리전스, LG전자·네이버 D2SF서 투자 ...
#      본문길이: 500자
#
# [12] "이재용·정의선·최태원 중 '원픽'은"...젠슨 황, 성공 기원 그룹 ...
#      본문길이: 500자
#
# [13] 카카오 첫 파업...'N% 성과급' 확산에 산업계 초긴장
#      본문길이: 500자
#
# [14] 카카오 첫 파업...'N% 성과급' 확산에 산업계 초긴장
#      본문길이: 500자
#
# [15] 최태원 "반도체 공장, 무조건 한국 아니다"…"전력·땅·물 다 갖춰져....
#      본문길이: 500자
#
# [16] 코스피 다시 '8천피' 아래로...4.5% 급락 7,730 마감
#      본문길이: 500자
#
# [17] 코스피 다시 '8천피' 아래로...4.5% 급락 7,730 마감
#      본문길이: 500자
#
# [18] 폭락 → 폭등 → 폭락...날마다 급변하는 '롤러코스피'
#      본문길이: 500자
#
# [19] [자막뉴스] 시도 때도 없이 울리는 '사이드카'...난생 처음보는 막...
#      본문길이: 500자
#
# [20] 폭락 → 폭등 → 폭락...날마다 급변하는 '롤러코스피'
#      본문길이: 500자
# 📄 총 20개 문서 임베딩 시작...
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# ✅ 20개 문서 벡터 저장 완료!

# %%
#RAG 체인 구성
from langchain_ollama import OllamaLLM
from langchain_core.prompts import PromptTemplate
from langchain_classic.chains import RetrievalQA 

def build_rag_chain(vectorstore):
    
    # 1. Ollama LLM 연결
    llm = OllamaLLM(model="llama3.2", temperature=0.1)
    
    # 2. 프롬프트 템플릿
    prompt_template = """
당신은 주식 뉴스 분석 전문가입니다.
아래 뉴스 기사들을 바탕으로 질문에 답해주세요.
반드시 한국어로 답변하고, 핵심 이슈를 간결하게 정리해주세요.

[참고 뉴스]
{context}

[질문]
{question}

[분석 결과]
"""
    
    PROMPT = PromptTemplate(
        template=prompt_template,
        input_variables=["context", "question"]
    )
    
    # 3. RAG 체인 구성
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=vectorstore.as_retriever(search_kwargs={"k": 5}),
        chain_type_kwargs={"prompt": PROMPT}
    )
    
    return qa_chain
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[46], line 2
#       1 #RAG 체인 구성
# ----> 2 from langchain_ollama import OllamaLLM
#       3 from langchain_core.prompts import PromptTemplate
#       4 from langchain_classic.chains import RetrievalQA
#       5
#
# ModuleNotFoundError: No module named 'langchain_ollama'

# %%
# RAG 체인 생성
chain = build_rag_chain(vectorstore)

# 질문
query = input("💬 질문을 입력하세요: ").strip()
result = chain.invoke({"query": query})
print("\n📊 분석 결과:")
print(result["result"])
# Out:
# 💬 질문을 입력하세요:  삼성전자 최근 이슈는?
# 📊 분석 결과:
# 삼성전자 recent 이슈는 주주명부 열람 소송이 나서, 소액주주 플랫폼 '액트'가 삼성전자를 상대로 주주명부 열람·등사 가처분 소송에 착수했다고 밝혔다. 또한, 대한민국 주주운동본부가 samsung전자와 SK하이닉스의 성과급 협약을 둘러싼 논란으로 인해 무효확인소송과 가처분 절차를 예고했다.
