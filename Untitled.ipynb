# %%
# 라이브러리 임포트
import requests
import pandas as pd
import time
from io import StringIO
from bs4 import BeautifulSoup
import yfinance as yf

# %%
#종목 검색 함수
def is_korean(text):
    return any("\uAC00" <= c <= "\uD7A3" for c in text)

def get_stock_code(stock_name):
    url = "https://kind.krx.co.kr/corpgeneral/corpList.do?method=download"
    response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
    response.encoding = "euc-kr"
    df = pd.read_html(StringIO(response.text))[0]
    df["종목코드"] = df["종목코드"].astype(str).str.strip()
    result = df[df["회사명"] == stock_name]["종목코드"]
    return result.values[0] if not result.empty else None

def translate_to_english(korean_name):
    url = "https://translate.googleapis.com/translate_a/single"
    params = {"client": "gtx", "sl": "ko", "tl": "en", "dt": "t", "q": korean_name}
    try:
        response = requests.get(url, params=params)
        return response.json()[0][0][0]
    except:
        return None

def get_yahoo_ticker(query):
    url = "https://query2.finance.yahoo.com/v1/finance/search"
    params = {"q": query, "lang": "en-US", "region": "US"}
    headers = {"User-Agent": "Mozilla/5.0"}
    try:
        response = requests.get(url, params=params, headers=headers)
        quotes = response.json().get("quotes", [])
        return quotes[0]["symbol"] if quotes else None
    except:
        return None

def search_stock(stock_name):
    if stock_name.isdigit() and len(stock_name) == 6:
        print(f"✅ [국내] 종목코드 직접 입력 → {stock_name}")
        return {"type": "KR", "code": stock_name, "name": stock_name}
    
    if is_korean(stock_name):
        code = get_stock_code(stock_name)
        if code:
            print(f"✅ [국내] {stock_name} → {code}")
            return {"type": "KR", "code": code, "name": stock_name}
        
        print(f"🔄 '{stock_name}' 번역 중...")
        english_name = translate_to_english(stock_name)
        print(f"🔄 번역 결과: {english_name}")
        
        if english_name:
            ticker = get_yahoo_ticker(english_name)
            if ticker:
                print(f"✅ [해외] {stock_name} → 티커: {ticker}")
                return {"type": "US", "code": ticker, "name": stock_name}
        
        print(f"❌ '{stock_name}'을 찾을 수 없어요.")
        print(f"💡 힌트: 영문명이나 티커로 직접 입력해보세요!")
        return None
    
    else:
        ticker = get_yahoo_ticker(stock_name)
        if ticker:
            print(f"✅ [해외] {stock_name} → 티커: {ticker}")
            return {"type": "US", "code": ticker, "name": stock_name}
        print(f"❌ '{stock_name}'을 찾을 수 없어요.")
        return None

# %%
# 뉴스 크롤링 함수
def get_article_body(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36",
        "Referer": "https://finance.naver.com"
    }
    try:
        # 1단계: 원래 URL 요청
        response = requests.get(url, headers=headers)
        response.encoding = "euc-kr"
        
        # 2단계: JS 리다이렉트 URL 추출
        if "top.location.href=" in response.text:
            import re
            match = re.search(r"top\.location\.href='(.+?)'", response.text)
            if match:
                real_url = match.group(1)
                response = requests.get(real_url, headers=headers)
                response.encoding = "utf-8"
        
        soup = BeautifulSoup(response.text, "html.parser")
        
        # n.news.naver.com 셀렉터
        selectors = [
            "div#dic_area",        # 네이버 뉴스 본문
            "div.newsct_article",  # 네이버 뉴스 본문 (구버전)
            "div#news_read",
            "div#contents",
        ]
        for selector in selectors:
            body = soup.select_one(selector)
            if body and body.text.strip():
                return body.text.strip()[:500]
        return ""
    except:
        return ""

def get_naver_finance_news(stock_info, num_articles=20):
    code = stock_info["code"]
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36",
        "Referer": "https://finance.naver.com"
    }
    results = []
    existing_links = set()  
    page = 1
    
    while len(results) < num_articles:
        url = f"https://finance.naver.com/item/news_news.naver?code={code}&page={page}"
        response = requests.get(url, headers=headers)
        response.encoding = "euc-kr"
        soup = BeautifulSoup(response.text, "html.parser")
        articles = soup.select("td.title a")
        
        if not articles:
            break
        
        for article in articles:
            if len(results) >= num_articles:
                break
            title = article.text.strip()
            link = "https://finance.naver.com" + article["href"]
            
            if link in existing_links:  
                continue
            
            body = get_article_body(link)
            results.append({"title": title, "link": link, "body": body})
            existing_links.add(link)
            time.sleep(0.3)
            print(f"✅ 수집완료 ({len(results)}/{num_articles}): {title[:30]}...")
        
        page += 1
        time.sleep(1)
    
    return results

def get_yahoo_news(ticker, num_articles=20):
    """yfinance로 해외 종목 뉴스 수집"""
    try:
        stock = yf.Ticker(ticker)
        news_data = stock.news
        
        if not news_data:
            print(f"❌ {ticker} 뉴스를 찾을 수 없어요!")
            return []
        
        results = []
        for item in news_data[:num_articles]:
            title = item.get("content", {}).get("title", "")
            link = item.get("content", {}).get("canonicalUrl", {}).get("url", "")
            summary = item.get("content", {}).get("summary", "")
            
            if title:
                results.append({
                    "title": title,
                    "link": link,
                    "body": summary
                })
                print(f"✅ 수집완료: {title[:30]}...")
        
        return results
    except Exception as e:
        print(f"❌ 오류 발생: {e}")
        return []


def get_news(stock_info, num_articles=20):
    if stock_info["type"] == "KR":
        print(f"📰 네이버 금융에서 수집 중...")
        return get_naver_finance_news(stock_info, num_articles)
    else:
        print(f"📰 야후 파이낸스에서 수집 중...")
        return get_yahoo_news(stock_info["code"], num_articles)

# %%
# ChromaDB 벡터 저장
import re
import warnings
warnings.filterwarnings("ignore")

from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_core.documents import Document

def store_to_chromadb(news_list, stock_name, stock_code):  
    docs = [
        Document(
            page_content=f"{news['title']}\n{news['body']}",
            metadata={"title": news["title"], "link": news["link"]}
        )
        for news in news_list if news["body"]
    ]
    
    print(f"📄 총 {len(docs)}개 문서 임베딩 시작...")
    
    if len(docs) == 0:
        print("❌ 저장할 문서가 없어요!")
        return None
    
    embedding_model = HuggingFaceEmbeddings(
        model_name="BAAI/bge-m3",
        model_kwargs={"device": "cpu"},
        encode_kwargs={"normalize_embeddings": True}
    )
    
    collection_name = f"news_{stock_code}"
    
    vectorstore = Chroma.from_documents(
        documents=docs,
        embedding=embedding_model,
        persist_directory=f"./chroma_db/{stock_code}",
        collection_name=collection_name
    )
    
    print(f"✅ {len(docs)}개 문서 벡터 저장 완료!")
    return vectorstore

# %%
stock_name = input("🔍 종목명을 입력하세요 (예: 삼성전자 / 엔비디아 / TSLA / 005930): ").strip()
result = search_stock(stock_name)

if result:
    news = get_news(result, num_articles=20)
    print(f"\n총 {len(news)}개 기사 수집 완료!")
    
    for i, n in enumerate(news):
        print(f"\n[{i+1}] {n['title']}")
        print(f"     본문길이: {len(n['body'])}자")
    
    vectorstore = store_to_chromadb(news, result["name"], result["code"])
# Out:
# 🔍 종목명을 입력하세요 (예: 삼성전자 / 엔비디아 / TSLA / 005930):  엔비디아
# 🔄 '엔비디아' 번역 중...
# 🔄 번역 결과: nvidia
# ✅ [해외] 엔비디아 → 티커: NVDA
# 📰 야후 파이낸스에서 수집 중...
# ✅ 수집완료: Is Oracle's Q4 earnings the ne...
# ✅ 수집완료: Risk-Averse Investors: Don't O...
# ✅ 수집완료: Gold Just Hit a New Low for 20...
# ✅ 수집완료: CPI Just Spelled Bad News for ...
# ✅ 수집완료: SK Hynix U.S. stock listing AD...
# ✅ 수집완료: 3 Semiconductor Stocks to Buy ...
# ✅ 수집완료: The Contrarian Case for Buying...
# ✅ 수집완료: Bargain Hunters: These 3 Divid...
# ✅ 수집완료: Stock Market Today: Dow Falls ...
# ✅ 수집완료: SpaceX Thinks Its AI Business ...
#
# 총 10개 기사 수집 완료!
#
# [1] Is Oracle's Q4 earnings the next big test for AI trade?
#      본문길이: 388자
#
# [2] Risk-Averse Investors: Don't Overlook This Simple Wealth-Building Tool
#      본문길이: 78자
#
# [3] Gold Just Hit a New Low for 2026, and This Might be Why
#      본문길이: 73자
#
# [4] CPI Just Spelled Bad News for Social Security COLA — Even Though it May Not Seem That Way
#      본문길이: 406자
#
# [5] SK Hynix U.S. stock listing ADR debut August 2026
#      본문길이: 121자
#
# [6] 3 Semiconductor Stocks to Buy Following the Recent Chip Sector Sell-Off
#      본문길이: 74자
#
# [7] The Contrarian Case for Buying Crypto in 2026
#      본문길이: 78자
#
# [8] Bargain Hunters: These 3 Dividend Stocks Recently Hit New 52-Week Lows
#      본문길이: 112자
#
# [9] Stock Market Today: Dow Falls After Trump Warning, CPI Inflation; Super Micro Tumbles (Live Coverage)
#      본문길이: 119자
#
# [10] SpaceX Thinks Its AI Business Has $26.5 Trillion in Potential. Here's Why It May Actually Be True.
#      본문길이: 53자
# 📄 총 10개 문서 임베딩 시작...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# ✅ 10개 문서 벡터 저장 완료!

# %%
#RAG 체인 구성
from langchain_ollama import OllamaLLM
from langchain_core.prompts import PromptTemplate
from langchain_classic.chains import RetrievalQA 

def build_rag_chain(vectorstore):
    
    # 1. Ollama LLM 연결
    llm = OllamaLLM(model="llama3.2", temperature=0.1)
    
    # 2. 프롬프트 템플릿
    prompt_template = """
당신은 주식 뉴스 분석 전문가입니다.
아래 뉴스 기사들을 바탕으로 질문에 답해주세요.
반드시 한국어로 답변하고, 핵심 이슈를 간결하게 정리해주세요.

[참고 뉴스]
{context}

[질문]
{question}

[분석 결과]
"""
    
    PROMPT = PromptTemplate(
        template=prompt_template,
        input_variables=["context", "question"]
    )
    
    # 3. RAG 체인 구성
    qa_chain = RetrievalQA.from_chain_type(
        llm=llm,
        chain_type="stuff",
        retriever=vectorstore.as_retriever(search_kwargs={"k": 5}),
        chain_type_kwargs={"prompt": PROMPT}
    )
    
    return qa_chain

# %%
# RAG 체인 생성
chain = build_rag_chain(vectorstore)

# 질문
query = input("💬 질문을 입력하세요: ").strip()
result = chain.invoke({"query": query})
print("\n📊 분석 결과:")
print(result["result"])
# Out:
# 💬 질문을 입력하세요:  엔비디아 최근 이슈는?
# 📊 분석 결과:
# ENTB디아 (Nvidia) 최근 이슈는 인공지능(AI) 분야의 지속적인 성장과 발전을 보인다. AI 분야는 semiconductor sector의 하락에 따라 지지받고 있는 것으로 보인다.
#
# 또한, 엔비디아는 recently의 Q2 2023의 수익성 향상과 새로운 제품 출시로 인해 지속적으로 성장하고 있다.
#
# ENTB디아의 최근 이슈를 요약하면 다음과 같다:
#
# * 인공지능(AI) 분야의 지속적인 성장과 발전
# * semiconductor sector의 하락에 따라 지지받고 있는 것으로 보인다.
# * Q2 2023의 수익성 향상과 새로운 제품 출시로 인해 지속적으로 성장하고 있다.
